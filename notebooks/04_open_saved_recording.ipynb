# %%
from pathlib import Path
recording = Path("runs/full_gyrac/run.rrd")
checkpoint = Path("runs/full_gyrac/checkpoints/final.pt")
print(f"Open viewer: rerun {recording}")
print(f"Checkpoint: {checkpoint}")
